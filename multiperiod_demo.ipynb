# %% [markdown]
# # ADVANCED PSE+ STAKEHOLDER SUMMIT I 2023:
# # Interactive Code Demonstration Using WaterTAP
#
# ### Today's demonstration will show
# - Part 1: how to build, initialize, simulate, and optimize a flowsheet for multiperiod analysis. The demonstration will demonstrate the use of a reverse osmosis (RO) unit model.
# - Part 2: :
#     - Public Github Repository: https://github.com/watertap-org/watertap
#     - Documentation: https://watertap.readthedocs.io/en/stable/
#     - Installer for User Interface: https://watertap-org.github.io/

# %% [markdown]
# # Overall approach to multiperiod flowsheets
# <p align="center">
#   <img src="assets/MP_Framework.png" height="320">
# </p>

# %% [markdown]
# ## Part 1: Build, setup, and simulate the multiperiod RO+PV+Battery flowsheet

# %% [markdown]
# <p align="center">
#   <img src="assets/RO_PV_Batt.svg">
# </p>

# %% [markdown]
# ## Multiperiod Setup
# #### Import Pyomo, IDAES, and WaterTAP packages

# %%
# Pyomo imports
from pyomo.environ import ConcreteModel, Objective, Var, value, units as pyunits

# IDAES imports
from idaes.core import FlowsheetBlock
from idaes.core.surrogate.pysmo_surrogate import PysmoSurrogate
from idaes.apps.grid_integration.multiperiod.multiperiod import MultiPeriodModel
from idaes.core.solvers.get_solver import get_solver
# import idaes.logger as idaeslog
from idaes.core.solvers.get_solver import get_solver

# %% [markdown]
# ### Import custom BatteryStorage model and define a method to define a battery

# %%
from steady_state_flowsheets.battery import BatteryStorage

def add_battery(m):
    """ This model does not use the flowsheet's time domain. Instead, it only models a single timestep, with initial
    conditions provided by `initial_state_of_charge` and `initial_energy_throughput`. The model calculates change
    in stored energy across a single time step using the power flow variables, `power_in` and `power_out`, and
    the `dr_hr` parameter."""

    m.fs.battery = BatteryStorage()
    m.fs.battery.charging_eta.set_value(0.95)    # Charging efficiency
    m.fs.battery.discharging_eta.set_value(0.95) # Discharging efficiency
    m.fs.battery.dt.set_value(1)                 # Time step

    return m.fs.battery

# %% [markdown]
# ### Define critical variables:

# %%
def define_system_vars(m):
    if "USD_2021" not in pyunits._pint_registry:
            pyunits.load_definitions_from_strings(
                ["USD_2021 = 500/708.0 * USD_CE500"]
            )

    m.fs.pv_to_ro = Var(
            initialize = 100,
            bounds = (0,None),
            units = pyunits.kW,
            doc = 'PV to RO electricity'
        )
    m.fs.grid_to_ro = Var(
            initialize = 100,
            bounds = (0,None),
            units = pyunits.kW,
            doc = 'Grid to RO electricity'
        )
    m.fs.curtailment = Var(
            initialize = 0,
            bounds = (0,None),
            units = pyunits.kW,
            doc = 'PV curtailment'
        )

    m.fs.elec_price = Var(
            initialize = m.fs.electricity_price,
            bounds = (0,None),
            units = pyunits.USD_2021,
            doc = 'Electric Cost'
        )

    m.fs.elec_generation = Var(
            initialize = m.fs.pv_gen,
            bounds = (0,None),
            units = pyunits.kW,
            doc = 'PV Power Gen'
        )

# %% [markdown]
# ### Add energy balance constraints

# %%
def add_steady_state_constraints(m):
    # Add energy flow balance
    @m.Constraint(doc="System energy flow")
    def eq_pv_elec_gen(b):
        return (
        m.fs.pv_gen == b.fs.pv_to_ro + b.fs.battery.elec_in[0] + b.fs.curtailment
        )

    @m.Constraint(doc="RO electricity requirment")
    def eq_ro_elec_req(b):
        return (m.fs.ro_elec_req == b.fs.pv_to_ro + b.fs.battery.elec_out[0] + b.fs.grid_to_ro
        )

    # Add grid electricity cost
    @m.Expression(doc="grid cost")
    def grid_cost(b):
        return (electricity_price * b.fs.grid_to_ro * b.fs.battery.dt)

# %%
def fix_dof_and_initialize(
    m,
):
    """Fix degrees of freedom and initialize the flowsheet

    This function fixes the degrees of freedom of each unit and initializes the entire flowsheet.

    Args:
        m: Pyomo `Block` or `ConcreteModel` containing the flowsheet
        outlvl: Logger (default: idaeslog.WARNING)
    """
    m.fs.battery.initialize()

    return

# %% [markdown]
# ### Create a Pyomo concrete model and steady-state flowsheet

# %%
def build_pv_battery_flowsheet(
        m = None,
        pv_gen = 1000,
        electricity_price = 0.1,
        ro_capacity = 6000,
        ro_elec_req = 944.3,
        pv_oversize = 1):
    """

    Returns:
        object: A Pyomo concrete optimization model and flowsheet
    """
    if m is None:
        m = ConcreteModel()
    m.fs = FlowsheetBlock(dynamic=False)

    m.fs.pv_gen = pv_gen
    m.fs.ro_elec_req = ro_elec_req
    m.fs.ro_capacity = ro_capacity
    m.fs.electricity_price = electricity_price
    m.fs.pv_size = pv_oversize*ro_elec_req

    add_battery(m)
    define_system_vars(m)
    add_steady_state_constraints(m)

    return m

# %%
m = build_pv_battery_flowsheet()
solver = get_solver()
fix_dof_and_initialize(m)
results = solver.solve(m)

for v in m.fs.component_data_objects(ctype=Var, active=True, descend_into=True):
        print(f'{str(v):<40s}', f'{value(v):<10,.1f}', pyunits.get_units(v))
# Out:
# ERROR: Rule failed for Expression 'grid_cost' with index None: NameError: name
#     'electricity_price' is not defined
# ERROR: Constructing component 'grid_cost' from data=None failed: NameError:
#     name 'electricity_price' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/f6/ln_247ms54b5y1mdczhdrr59rtfn88/T/ipykernel_1263/4151090915.py in <cell line: 1>()
# ----> 1 m = build_pv_battery_flowsheet()
#       2 solver = get_solver()
#       3 fix_dof_and_initialize(m)
#       4 results = solver.solve(m)
#       5
#
# /var/folders/f6/ln_247ms54b5y1mdczhdrr59rtfn88/T/ipykernel_1263/2118186405.py in build_pv_battery_flowsheet(m, pv_gen, electricity_price, ro_capacity, ro_elec_req, pv_oversize)
#      23     add_battery(m)
#      24     define_system_vars(m)
# ---> 25     add_steady_state_constraints(m)
#      26
#      27     return m
#
# /var/folders/f6/ln_247ms54b5y1mdczhdrr59rtfn88/T/ipykernel_1263/144590172.py in add_steady_state_constraints(m)
#      14     # Add grid electricity cost
#      15     @m.Expression(doc="grid cost")
# ---> 16     def grid_cost(b):
#      17         return (electricity_price * b.fs.grid_to_ro * b.fs.battery.dt)
#
# /opt/anaconda3/envs/watertap-seto-dev-env/lib/python3.10/site-packages/pyomo/core/base/block.py in __call__(self, rule)
#      73
#      74     def __call__(self, rule):
# ---> 75         setattr(
#      76             self._block,
#      77             rule.__name__,
#
# /opt/anaconda3/envs/watertap-seto-dev-env/lib/python3.10/site-packages/pyomo/core/base/block.py in __setattr__(self, name, val)
#     647                 # Pyomo components are added with the add_component method.
#     648                 #
# --> 649                 self.add_component(name, val)
#     650             else:
#     651                 #
#
# /opt/anaconda3/envs/watertap-seto-dev-env/lib/python3.10/site-packages/pyomo/core/base/block.py in add_component(self, name, val)
#    1217                              _blockName, str(data))
#    1218             try:
# -> 1219                 val.construct(data)
#    1220             except:
#    1221                 err = sys.exc_info()[1]
#
# /opt/anaconda3/envs/watertap-seto-dev-env/lib/python3.10/site-packages/pyomo/core/base/expression.py in construct(self, data)
#     374             # We do not (currently) accept data for constructing Constraints
#     375             assert data is None
# --> 376             self._construct_from_rule_using_setitem()
#     377         finally:
#     378             timer.report()
#
# /opt/anaconda3/envs/watertap-seto-dev-env/lib/python3.10/site-packages/pyomo/core/base/indexed_component.py in _construct_from_rule_using_setitem(self)
#     713                 # Slight optimization: if the initializer is known to be
#     714                 # constant, then only call the rule once.
# --> 715                 val = rule(block, None)
#     716                 for index in self.index_set():
#     717                     self._setitem_when_not_present(index, val)
#
# /opt/anaconda3/envs/watertap-seto-dev-env/lib/python3.10/site-packages/pyomo/core/base/initializer.py in __call__(self, parent, idx)
#     421
#     422     def __call__(self, parent, idx):
# --> 423         return self._fcn(parent)
#     424
#     425     def constant(self):
#
# /var/folders/f6/ln_247ms54b5y1mdczhdrr59rtfn88/T/ipykernel_1263/144590172.py in grid_cost(b)
#      15     @m.Expression(doc="grid cost")
#      16     def grid_cost(b):
# ---> 17         return (electricity_price * b.fs.grid_to_ro * b.fs.battery.dt)
#
# NameError: name 'electricity_price' is not defined

# %% [markdown]
# ## Refresh - approach to multiperiod flowsheets
# <p align="center">
#   <img src="assets/MP_Framework.png" height="320">
# </p>

# %%
def get_pv_ro_variable_pairs(t1, t2):
    """
    This function returns pairs of variables that need to be connected across two time periods

    Args:
        t1: current time block
        t2: next time block

    Returns:
        None
    """
    return [
        (t1.fs.battery.state_of_charge[0], t2.fs.battery.initial_state_of_charge),
        (t1.fs.battery.energy_throughput[0], t2.fs.battery.initial_energy_throughput),
        (t1.fs.battery.nameplate_power, t2.fs.battery.nameplate_power),
        (t1.fs.battery.nameplate_energy, t2.fs.battery.nameplate_energy),
        ]

# %%
def add_pv_ro_constraints(mp):
    """
    This function adds constraints that connect variables across two time periods

    Args:
        m: Pyomo model

    Returns:
        None
    """

    cost_battery_power = 75 # $/kW
    cost_battery_energy = 50 # $/kWh  
    n_time_points= 7*24
    ro_capacity = 6000 # m3/day

    @mp.Expression(doc="battery cost")
    def battery_capital_cost(b):
        return ((cost_battery_power * b.blocks[0].process.fs.battery.nameplate_power +
                 cost_battery_energy * b.blocks[0].process.fs.battery.nameplate_energy))
        
    # Add PV cost function
    @mp.Expression(doc="PV cost")
    def pv_capital_cost(b):
        return (0.37 * 1000 * b.blocks[0].process.fs.pv_size +
                0.03 * 1000 * b.blocks[0].process.fs.pv_size)

    @mp.Expression(doc="Capital cost")
    def total_capital_cost(b):
        return (b.battery_capital_cost + b.pv_capital_cost)
    
    @mp.Expression(doc="Annualized Capital cost")
    def annualized_capital_cost(b):
        return (b.total_capital_cost / 20)

    # Total cost
    @mp.Expression(doc='total cost')
    def total_cost(b):
        # The annualized capital cost is evenly distributed to the multiperiod
        return (
            (b.annualized_capital_cost) / 365 / 24 * n_time_points
            + sum([b.blocks[i].process.grid_cost for i in range(n_time_points)])
        )

    # LCOW
    @mp.Expression(doc='total cost')
    def LCOW(b):
        # LCOW from RO: 0.45
        return (
            0.40 + b.total_cost / (n_time_points*pyunits.convert(ro_capacity * pyunits.m**3 / pyunits.day, to_units=pyunits.m**3 / pyunits.hour))
        )   

    # Set objective
    mp.obj = Objective(expr=mp.LCOW)

# %%
def unfix_dof(m):
    """
    This function unfixes a few degrees of freedom for optimization

    Args:
        m: object containing the integrated nuclear plant flowsheet

    Returns:
        None
    """
    m.fs.battery.nameplate_energy.unfix()
    m.fs.battery.nameplate_power.unfix()

# %%
import pandas as pd

def load_surrogate(surrogate_filename='demo_surrogate.json'):
    return PysmoSurrogate.load_from_file(surrogate_filename)

def eval_surrogate(surrogate, design_size, Hour, Day):
    input = pd.DataFrame.from_dict([{'design_size':design_size, 'Hour':Hour, 'Day':Day}], orient='columns')
    hourly_gen = surrogate.evaluate_surrogate(input)
    return hourly_gen.values[0][0]

# %%
def load_flowsheet_options(mp,
        n_time_points= 7*24,
        ro_capacity = 6000, # m3/day
        ro_elec_req = 1000, # kW
        pv_oversize = 1,
        surrogate = None):
    
    flowsheet_options={ t: { 
                            "pv_gen": 1000,
                            "electricity_price": 0.1,
                            "ro_capacity": ro_capacity, 
                            "ro_elec_req": ro_elec_req,
                            "pv_oversize": pv_oversize} 
                            for t in range(n_time_points)
    }

    # create the multiperiod object
    mp.build_multi_period_model(
        model_data_kwargs=flowsheet_options,
        flowsheet_options={ "ro_capacity": ro_capacity, 
                            "ro_elec_req": ro_elec_req},)

# %%
def create_multiperiod_pv_battery_model(
        n_time_points= 7*24,        
    ):
    
    mp = MultiPeriodModel(
        n_time_points=n_time_points,
        process_model_func=build_pv_battery_flowsheet,
        linking_variable_func=get_pv_ro_variable_pairs,
        initialization_func=fix_dof_and_initialize,
        unfix_dof_func=unfix_dof,
    )

    # surrogate = load_surrogate()
    load_flowsheet_options(mp)
    mp.blocks[0].process.fs.battery.initial_state_of_charge.fix(0)
    add_pv_ro_constraints(mp)
    
    return mp

# %%
mp = create_multiperiod_pv_battery_model()
results = solver.solve(mp)
# Out:
# [+   0.00] Beginning the formulation of the multiperiod optimization problem.
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[0]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[1]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[2]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[3]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[4]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[5]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[6]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[7]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[8]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[9]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[10]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[11]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[12]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[13]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[14]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[15]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[16]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[17]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[18]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[19]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[20]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[21]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[22]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[23]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[24]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[25]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[26]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[27]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[28]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[29]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[30]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[31]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[32]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[33]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[34]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[35]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[36]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[37]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[38]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[39]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[40]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[41]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[42]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[43]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[44]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[45]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[46]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[47]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[48]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[49]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[50]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[51]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[52]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[53]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[54]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[55]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[56]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[57]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[58]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[59]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[60]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[61]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[62]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[63]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[64]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[65]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[66]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[67]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[68]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[69]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[70]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[71]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[72]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[73]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[74]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[75]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[76]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[77]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[78]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[79]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[80]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[81]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[82]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[83]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[84]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[85]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[86]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[87]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[88]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[89]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[90]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[91]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[92]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[93]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[94]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[95]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[96]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[97]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[98]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[99]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[100]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[101]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[102]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[103]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[104]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[105]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[106]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[107]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[108]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[109]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[110]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[111]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[112]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[113]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[114]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[115]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[116]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[117]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[118]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[119]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[120]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[121]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[122]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[123]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[124]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[125]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[126]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[127]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[128]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[129]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[130]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[131]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[132]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[133]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[134]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[135]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[136]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[137]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[138]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[139]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[140]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[141]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[142]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[143]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[144]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[145]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[146]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[147]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[148]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[149]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[150]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[151]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[152]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[153]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[154]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[155]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[156]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[157]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[158]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[159]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[160]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[161]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[162]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[163]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[164]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[165]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[166]
# 2023-10-05 13:02:47 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: ...Constructing the flowsheet model for blocks[167]
# [+   0.29] Completed the formulation of the multiperiod optimization problem.
# 2023-10-05 13:02:47 [INFO] idaes.init.fs.battery: Battery initialization status optimal - Optimal Solution Found.
# [+   0.06] Created an instance of the flowsheet and initialized it.
# [+   0.03] Initialized the entire multiperiod optimization model.
# [+   0.00] Unfixed the degrees of freedom from each period model.

# %%
labels = ['pv_size', 'battery_power', 'battery_energy', 'LCOW']
for idx, v in enumerate([mp.blocks[0].process.fs.pv_size, mp.blocks[0].process.fs.battery.nameplate_power, mp.blocks[0].process.fs.battery.nameplate_energy, mp.LCOW]):
    print(f'{labels[idx]:<20s}', f'{value(v):<10,.2f}')
# Out:
# pv_size              1,000.00
# battery_power        27.60
# battery_energy       40.43
# LCOW                 0.41

# %%
from util.visualize import create_plot
create_plot(mp, elec_prices)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/f6/ln_247ms54b5y1mdczhdrr59rtfn88/T/ipykernel_42034/2892539084.py in <cell line: 2>()
#       1 from util.visualize import create_plot
# ----> 2 create_plot(mp, elec_prices)
#
# NameError: name 'elec_prices' is not defined
